# %%
import seaborn as sns

# %%
taxi_df = sns.load_dataset("taxis")
taxi_df.to_csv(r"taxi datei.csv")
sns.boxplot(taxi_df, x="total")
# Out:
# c:\Users\User\.conda\envs\datacraft\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='total'>
